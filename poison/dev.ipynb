# %%
import ray
from utils import StyleTransferParaphraser
import datasets
import logging

if ray.is_initialized:
    ray.shutdown()
    ray.shutdown()
ray.init(logging_level=logging.ERROR)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 8
#       6 if ray.is_initialized:
#       7     ray.shutdown()
# ----> 8 ray.init(logging_level=logging.ERROR)
#
# File /nas03/terry69/anaconda3/envs/alignment/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# ...

# %%
data = datasets.load_from_disk(
    "/nas03/terry69/backdoorEval/clean/base/ultrachat_100k/train_sft")
para_ref = ray.put(StyleTransferParaphraser(
    "Bible", upper_length="same_100"))  # can be up to 100
# scpn = ray.put(OpenAttack.attackers.SCPNAttacker().gen_paraphrase)


@ray.remote(num_gpus=0.1, num_cpus=1)
def generate(x, model):
    output = model.generate(x)
    return output[0].strip()
